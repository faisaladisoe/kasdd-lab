# %% [markdown]
# <center>
# <img src="https://drive.google.com/uc?id=1f1gGVI-rxcHjA90WEGNvvtSXF1pAxQwg" alt="Fasilkom UI" width="300"/>
#
# CSGE603130 • Kecerdasan Artifisial dan Sains Data Dasar
#
# Semester Genap 2021/2022
#
# Fakultas Ilmu Komputer, Universitas Indonesia
#
# ##**Lab 2: *Statistics & Data Visualization***
#
# ###**Tenggat Waktu: 26 Februari 2022, 23.55 WIB**
# </center>
#
# ####**Ketentuan:**
#
# 1. Dokumen *template* lab dengan format .ipynb dan dataset (jika dibutuhkan) telah disediakan di SCeLe
# 2. Jalankan kode pada dokumen .ipynb dan perhatikan dengan saksama apa yang potongan kode tersebut lakukan beserta dengan keluarannya. Jawablah **pertanyaan yang disisipkan** pada potongan program yang diberikan.
# 3. Dokumen Jupyter Notebook yang telah dilengkapi dengan jawaban dikumpulkan dengan format penamaan **Kelas_LabX_NPM_Nama.ipynb**. Contoh: A_Lab2_2006560996_Median Hardiv Nugraha.ipynb
# 4. Kumpulkan dokumen tersebut pada submisi yang telah disediakan di SCeLe sesuai dengan kelas masing-masing sebelum **26 Februari 2022, 23.55 WIB**. Keterlambatan pengumpulan akan dikenakan pinalti.
# 5. Lab ini dirancang sebagai **tugas mandiri**. Plagiarisme tidak diperkenankan dalam bentuk apapun. Adapun kolaborasi berupa diskusi (tanpa menyalin maupun mengambil jawaban orang lain) dan literasi masih diperbolehkan dengan mencantumkan kolaborator dan sumber.

# %% [markdown]
# ## **Pernyataan Integritas**
#
# Wajib diisi. Tanpa pernyataan integritas submisi akan dikenakan penalti.

# %%
# Isi dengan data diri Anda
NAMA = "Muhammad Faisal Adi Soesatyo"
KELAS = "B"
NPM = "1906293184"

# Isi dengan NPM teman yang berdiskusi dengan Anda
KOLABORATOR = []

# Isi dengan sumber referensi yang Anda gunakan dalam mengerjakan
REFERENSI = [
             "https://numpy.org/doc/stable/reference/routines.statistics.html",
             "https://seaborn.pydata.org/generated/seaborn.heatmap.html",
             "https://medium.com/@szabo.bibor/how-to-create-a-seaborn-correlation-heatmap-in-python-834c0686b88e",
             "https://www.python-graph-gallery.com/bubble-plot-with-seaborn",
             "https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51#:~:text=A%20boxplot%20is%20a%20standardized,and%20what%20their%20values%20are."
        ]

# %%
PERNYATAAN_INTEGRITAS = "Saya, %s dari kelas %s dengan NPM %s, menyatakan bahwa seluruh jawaban pada pekerjaan ini murni saya kerjakan sendiri.\n\
Saya tidak mencontek jawaban, memberikan jawaban, maupun menyalin dari sumber manapun.\n \
\n\
Jika saya melanggar pernyataan tersebut, saya siap menerima konsekuensi apapun yang diberikan.\n   \
(%s)" % (NAMA, KELAS, NPM, NAMA)

print(PERNYATAAN_INTEGRITAS)
# Out:
# Saya, Muhammad Faisal Adi Soesatyo dari kelas B dengan NPM 1906293184, menyatakan bahwa seluruh jawaban pada pekerjaan ini murni saya kerjakan sendiri.
# Saya tidak mencontek jawaban, memberikan jawaban, maupun menyalin dari sumber manapun.
#
# Jika saya melanggar pernyataan tersebut, saya siap menerima konsekuensi apapun yang diberikan.
#    (Muhammad Faisal Adi Soesatyo)

# %% [markdown]
# Contoh Penggunaan Visualisasi menggunakan Matplotlib dan Seaborn dapat dilihat pada notebook **Lab 2 - DataViz Reference.ipynb**

# %% [markdown]
# This section is modified by Asisten Dosen KASDD Ganjil 2021/2022

# %% [markdown]
# # Exploratory Data Analysis
#
# *Exploratory Data Analysis* (EDA) merupakan suatu proses menganalisis dataset untuk melihat karakteristik utama dari data. EDA adalah pemrosesan dasar yang dapat mempengaruhi keputusan-keputusan seorang data scientist dalam memproses data di tahap selanjutnya. Proses ini sering melibatkan dua hal, di antaranya *descriptive statistics* dan data *visualization*.

# %% [markdown]
# ## Deskripsi Dataset Avocado
#
# Tabel di bawah menunjukkan data pemindaian ritel mingguan 2018 untuk volume (unit) dan harga ritel Nasional. Data pemindaian ritel datang langsung dari pengecer berdasarkan penjualan eceran asli alpukat jenis Hass. Mulai tahun 2013, tabel di bawah ini mencerminkan kumpulan data ritel multi-outlet. AveragePrice di tabel mencerminkan biaya per unit (per alpukat). Kode Pencarian Produk (PLU) di tabel hanya untuk alpukat Hass. Varietas alpukat lainnya (misalnya kulit hijau) tidak termasuk dalam tabel ini.
#
# * `Date`: the date of the observation
# * `AveragePrice`: the average price of a single avocado
# * `Total Volume`: total weight of avocados sold
# * `4046`: total weight of avocados with PLU 4046 sold
# * `4225`: total weight of avocados with PLU 4225 sold
# * `4770`: total weight of avocados with PLU 4770 sold
# * `Total Bags`: total weight of sold avocados put in bags (excluding those with PLUs)
# * `Small Bags`: total weight of sold avocados put in small bags
# * `Large Bags`: total weight of sold avocados put in large bags
# * `XLarge Bags`: total weight of sold avocados put in extra large bags
# * `type`: conventional or organic
# * `year`: the year
# * `region`: the city or region of the observation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import scipy.stats as scp
from numpy.polynomial.polynomial import polyfit

# %%
# Import dataset menggunakan Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import dataset dengan index di kolom pertama 
# avocado_df = pd.read_csv('/content/drive/My Drive/Kuliah/KASDD/KASDD Asdos/Lab/Lab 2/avocado.csv')
avocado_df = pd.read_csv('avocado.csv')

# %%
total_rows, total_attributes = avocado_df.shape
print('Jumlah data:', total_rows)
print("Jumlah atribut:", total_attributes)
avocado_df.drop(columns=avocado_df.columns[0], 
        axis=1, 
        inplace=True)
avocado_df.head()
# Out:
# Jumlah data: 18249
# Jumlah atribut: 14
#          Date  AveragePrice  Total Volume  ...          type  year  region
# 0  2015-12-27          1.33      64236.62  ...  conventional  2015  Albany
# 1  2015-12-20          1.35      54876.98  ...  conventional  2015  Albany
# 2  2015-12-13          0.93     118220.22  ...  conventional  2015  Albany
# 3  2015-12-06          1.08      78992.15  ...  conventional  2015  Albany
# 4  2015-11-29          1.28      51039.60  ...  conventional  2015  Albany
#
# [5 rows x 13 columns]

# %%
# Melihat kolom-kolom pada dataframe
avocado_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# Terlihat sekilas tipe dan jumlah non-null dari setiap kolom. Dari informasi ini, kita mengetahui tidak ada kolom yang memiliki null untuk dataset avocado (karena semua kolom memiliki jumlah yang sama dengan jumlah data).

# %%
# Menampilkan statistics untuk setiap atribut numerik 
avocado_df.describe()
# Out:
#        AveragePrice  Total Volume  ...    XLarge Bags          year
# count  18249.000000  1.824900e+04  ...   18249.000000  18249.000000
# mean       1.405978  8.506440e+05  ...    3106.426507   2016.147899
# std        0.402677  3.453545e+06  ...   17692.894652      0.939938
# min        0.440000  8.456000e+01  ...       0.000000   2015.000000
# 25%        1.100000  1.083858e+04  ...       0.000000   2015.000000
# 50%        1.370000  1.073768e+05  ...       0.000000   2016.000000
# 75%        1.660000  4.329623e+05  ...     132.500000   2017.000000
# max        3.250000  6.250565e+07  ...  551693.650000   2018.000000
#
# [8 rows x 10 columns]

# %%
# Menampilkan statistics untuk setiap atribut non-numerik atau kategorik
avocado_df.describe(include=np.object)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#               Date          type  region
# count        18249         18249   18249
# unique         169             2      54
# top     2015-12-27  conventional  Albany
# freq           108          9126     338

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# Ada banyak jenis measures yang dapat diterapkan untuk *descriptive statistics*.
#
# Mengingat materi dari StatProb, ada
# 1. *Central tendency* (mean, median, mode)
# 2. *Dispersion* atau *variability* (variance, standard deviation)
# 3. Minimum, maximum
# 4. Range
# 5. Quantile
# 6. Percentile
#
# **Central tendency sering dipakai untuk melihat distribusi data.**
# Pada biasanya, `mean` lebih cocok untuk distribusi normal (yang terlihat simetris di tengah), sementara median lebih baik untuk distribusi bersifat *skewed* (berat sebelah). Tentunya, ini tidak berlaku untuk data kategorik yang hanya bisa menggunakan `mode`.
#
# Terkadang central tendency saja tidak cukup untuk melihat distribusi data. Central tendency tidak bisa menggambarkan seberapa besar data tersebar. **Measure of dispersion merupakan ukuran yang biasa digunakan untuk melihat keragaman data atau seberapa besar data tersebar.** Terdapat beberapa ukuran untuk menentukan dispersi data pengamatan, seperti jangkauan/rentang (`range`) dan simpangan baku (`standard deviation`).
#
# Secara umum, berikut adalah contoh penggunaan descriptive statistics (1), (2), (3) dari atribut `AveragePrice`:

# %%
# Array of 'AveragePrice' values
price_arr = avocado_df['AveragePrice']

price_stats = [
    ['Mean', np.mean(price_arr)],
    ['Median', np.median(price_arr)],
    ['Mode', scp.mode(price_arr)[0][0]],
    ['Standard Deviation', np.std(price_arr)],
    ['Variance', np.var(price_arr)],
    ['Minimum', np.min(price_arr)],
    ['Maximum', np.max(price_arr)],
]

pd.DataFrame(price_stats, columns=['Measure', 'Value'])
# Out:
#               Measure     Value
# 0                Mean  1.405978
# 1              Median  1.370000
# 2                Mode  1.150000
# 3  Standard Deviation  0.402666
# 4            Variance  0.162140
# 5             Minimum  0.440000
# 6             Maximum  3.250000

# %% [markdown]
# Pada hasil di atas, kita dapat lihat bahwa `mean` > `median` > `mode`. Dengan nilai maksimum 3.25 dan minimum 0.44 ada kemungkinan bahwa data cenderung padat di nilai yang rendah atau padat ke kiri.

# %% [markdown]
# Diluar central tendency dan dispersion, statistik deskriptif juga mencakup ***skewness* yang mengukur kemiringan atau asimetri distribusi**. *Skewness* dari data dapat mempengaruhi pemrosesan, contohnya menangani *missing values* dengan *central tendency* yang tepat atau melakukan *sampling*.
#
# Cara melihat *skewness* dapat dilakukan melalui visualisasi KDE (Kernel Density Estimation) plot. KDE plot menunjukkan estimasi dari fungsi probabilitas *density* pada sebuah data yang bersifat kontinu.

# %%
# KDE Plot (Distribusi data) dari AveragePrice

plt.figure(figsize=(7,5))
sns.kdeplot(price_arr, shade=True)
plt.vlines(x=np.mean(price_arr), ymin=0, ymax=1, color='blue', linestyle='--')
plt.vlines(x=np.median(price_arr), ymin=0, ymax=1, color='brown', linestyle='--')
plt.vlines(x=scp.mode(price_arr)[0][0], ymin=0, ymax=1, color='red', linestyle='--')
plt.legend(['AveragePrice', 'Mean', 'Median', 'Mode'], fontsize=12)
plt.show()

# %% [markdown]
# Terlihat bahwa distribusi bersifat skewed karena sedikit lebih berat di kiri. Berdasarkan visualisasi, median, mean, dan modus tidak selalu sama. Pada kasus ini, terlihat bahwa median dapat menjadi pengukuran yang paling tepat untuk menggambarkan central tendency dari data.

# %% [markdown]
# Selain itu, kita dapat mengecek nilai skewness dari atribut-atribut numerik dengan menggunakan fungsi `.skew()` berikut:

# %%
# Mengambil hanya atribut float numerik
numeric_avocado = avocado_df.select_dtypes(include=['float64'])

# Mengecek nilai skewness dari data
numeric_avocado.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# dtype: float64

# %% [markdown]
# Interpretasi nilai *skewness*:
# *   Jika nilainya positif maka right skewed (buntut kanan > buntut kiri)
# *   Jika nilainya negatif maka left skewed (buntut kiri > buntut kanan)
# *   Jika skewness = 0, data simetris
#
# Dari hasil tersebut, didapati bahwa AveragePrice memiliki karakteristik right skewed dengan tingkat asimetris yang tidak terlalu tinggi. Sementara atribut numerik lain memiliki asimetris yang sangat tinggi ke kanan.

# %% [markdown]
# Untuk membandingkan distribusi data A ke data B, kita dapat menggunakan overlapping Histogram atau KDE plot.
#
# Misalkan kita ingin melihat perbandingan `AveragePrice` dari conventional vs organic avocados.

# %%
conventional = avocado_df[avocado_df['type'] == "conventional"]
organic = avocado_df[avocado_df['type'] == "organic"]
conv_price = conventional['AveragePrice']
org_price = organic['AveragePrice']

# Histogram dengan "density=True" untuk menyerupai KDE Plot
plt.figure(figsize=(7,5))
plt.title("Average Prices per Avocado Type", fontsize=12)
plt.hist(conv_price, alpha=0.5, bins=50, density=True, label="Conventional")
plt.hist(org_price, alpha=0.5, bins=50, density=True, label="Organic")
plt.xlabel("AveragePrice")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
# KDE Plot
plt.figure(figsize=(7,5))
sns.kdeplot(conv_price, shade=True)
sns.kdeplot(org_price, shade=True)
plt.legend(['Conventional','Organic'], fontsize=12)
plt.vlines(x=conv_price.mean(), ymin=0, ymax=1.6, color='blue', linestyle='--')
plt.vlines(x=org_price.mean(), ymin=0, ymax=1.2, color='brown', linestyle='--')
plt.show()

# %% [markdown]
# ## Correlation
#
# Korelasi merupakan pengukuran dependensi antar atribut dalam data. Korelasi sering digunakan untuk mengukur apakah suatu atribut memiliki hubungan yang kuat secara linier atau tidak.
#
# Terdapat beberapa jenis korelasi yang dapat digunakan pada jenis data yang berbeda. ***Pearson correlation*** umum digunakan untuk mengukur korelasi pada atribut numerik.

# %%
# Menampilkan nilai korelasi atribut numerik (dari koefisien Pearson)
avocado_df.corr(method='pearson')
# Out:
#               AveragePrice  Total Volume  ...  XLarge Bags      year
# AveragePrice      1.000000     -0.192752  ...    -0.117592  0.093197
# Total Volume     -0.192752      1.000000  ...     0.747157  0.017193
# 4046             -0.208317      0.977863  ...     0.699377  0.003353
# 4225             -0.172928      0.974181  ...     0.688809 -0.009559
# 4770             -0.179446      0.872202  ...     0.679861 -0.036531
# Total Bags       -0.177088      0.963047  ...     0.804233  0.071552
# Small Bags       -0.174730      0.967238  ...     0.806845  0.063915
# Large Bags       -0.172940      0.880640  ...     0.710858  0.087891
# XLarge Bags      -0.117592      0.747157  ...     1.000000  0.081033
# year              0.093197      0.017193  ...     0.081033  1.000000
#
# [10 rows x 10 columns]

# %% [markdown]
# Dari korelasi Pearson diatas, kita bisa menentukan pasangan atribut apa saja yang memiliki relasi yang tinggi. Untuk membuktikan, di bawah terdapat 3 scatterplot yang menunjukkan hubungan linear dengan `Total Volume`, yakni
# * `Total Bags`: 0.96 (terlihat berbanding lurus naik)
# * `AveragePrice`: -0.19 (ada sedikit tren terbalik tetapi semua hampir berkumpul di total volume 0 - 1)
# * `year`: 0.01 (membingungkan)

# %%
w = avocado_df["Total Volume"]
z = avocado_df["Total Bags"]
avocado_df.plot.scatter(x="Total Volume", y="Total Bags", figsize=(6,4))
b, m = polyfit(w, z, 1)
plt.plot(w, b + m * w, '-')
plt.show()

# %% [markdown]
# Dari visualisasi tersebut kita dapat melihat bahwa `Total Bags` berbanding lurus dengan `Total Volume`. Semakin tinggi `Total Bags`, maka `Total Volume` juga akan meningkat (tentu sangat masuk akal).

# %%
z = avocado_df["AveragePrice"]
avocado_df.plot.scatter(x="Total Volume", y="AveragePrice", figsize=(6,4))
b, m = polyfit(w, z, 1)
plt.plot(w, b + m * w, '-')
plt.show()

# %% [markdown]
# Antara `Total Volume` dan `AveragePrice` kita dapati bahwa terjadi hubungan yang negatif di mana peningkatan volume menyebabkan harga menurun. Hal ini mungkin terjadi karena penjualan yang agresif (mungkin seperti penjualan grosir dan sebagainya).

# %%
z = avocado_df["year"]
avocado_df.plot.scatter(x="Total Volume", y="year", figsize=(6,4))
b, m = polyfit(w, z, 1)
plt.ylim(ymin=2014,ymax=2019)
plt.plot(w, b + m * w, '-')
plt.show()

# %% [markdown]
# Dari visualisasi di atas, kita mungkin menemui perhitungan dan visualisasi yang agak membingungkan. Hal ini wajar terjadi dikarenakan tahun yang dianggap sebagai data numerik sedangkan lebih tepat dianggap sebagai data kategorik. Tipe data akan sangat mempengaruhi pemrosesan di EDA, maka kita perlu berhati-hati untuk menentukan tipe data yang sesuai.

# %% [markdown]
# ## Data Visualization

# %%
# Fungsi yang membuat plot untuk melihat distribusi frekuensi untuk satu kolom/atribut
def countplot(column, df):
    return sns.countplot(x=column, data=df)

# %%
countplot('type', avocado_df)

# %% [markdown]
# Sekilas dari countplot, atribut `type` memiliki data yang sangat seimbang.

# %%
countplot('year', avocado_df)

# %% [markdown]
# Sedangkan, atribut `year` menandakan kalau data dari 2018 jauh lebih sedikit dibanding tahun-tahun sebelumnya. Hal ini wajar terjadi karena dataset memang diambil pada pertengahan tahun 2018.

# %%
# Menampilkan boxplot type terhadap average price per tahun
sns.boxplot(x="type", y="AveragePrice", hue="year", data=avocado_df)

# %% [markdown]
# Terlihat bahwa avocado bertipe `organic` memiliki rata-rata harga (`AveragePrice`) yang lebih tinggi dibanding dengan yang bertipe `conventional` setiap tahunnya.

# %%
# Menampilkan boxplot type terhadap total volume per tahun
sns.boxplot(x="type", y="Total Volume", hue="year", data=avocado_df)

# %% [markdown]
# Jika dilihat dari total volume yang terjual, terlihat sepertinya avocado memiliki "outliers" yang cukup banyak dan jauh dari IQR sampai boxplotnya sendiri tidak terlihat.

# %%
# Menampilkan boxplot untuk atribut yang memiliki banyak unique values (seperti region) terhadap average price
fig = px.box(avocado_df, x='region', y='AveragePrice')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="47f50a2f-04eb-4eb4-b0df-9213df24d5ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47f50a2f-04eb-4eb4-b0df-9213df24d5ce")) {                    Plotly.newPlot(                        "47f50a2f-04eb-4eb4-b0df-9213df24d5ce",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>AveragePrice=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","Buffa ...

# %% [markdown]
# ## Latihan Soal

# %% [markdown]
# ### **SOAL 1: Descriptive Statistics**
#
# (a) Tampilkan descriptive statistics dari atribut `Total Volume`! Tampilkan juga informasi berupa range, Q1, Q2, Q3, 20th Percentile sebagai tambahan informasi!

# %%
# 1(a) Implementasi kode di sini
totalVolume = avocado_df['Total Volume']
volumeStats = [
    ['Mean', np.mean(totalVolume)],
    ['Median', np.median(totalVolume)],
    ['Mode', scp.mode(totalVolume)[0][0]],
    ['Standard Deviation', np.std(totalVolume)],
    ['Variance', np.var(totalVolume)],
    ['Minimum', np.min(totalVolume)],
    ['Maximum', np.max(totalVolume)],
    ['Q1', np.quantile(totalVolume, .25)],
    ['Q2', np.quantile(totalVolume, .5)],
    ['Q3', np.quantile(totalVolume, .75)],
    ['20th Percentile', np.percentile(totalVolume, 20)]
]
pd.DataFrame(volumeStats, columns=['Measure', 'Value'])
# Out:
#                Measure         Value
# 0                 Mean  8.506440e+05
# 1               Median  1.073768e+05
# 2                 Mode  2.038990e+03
# 3   Standard Deviation  3.453451e+06
# 4             Variance  1.192632e+13
# 5              Minimum  8.456000e+01
# 6              Maximum  6.250565e+07
# 7                   Q1  1.083858e+04
# 8                   Q2  1.073768e+05
# 9                   Q3  4.329623e+05
# 10     20th Percentile  8.168866e+03

# %% [markdown]
# :(b) Apa central tendency paling cocok untuk atribut `Total Volume`? Berikan alasan!

# %%
# 1(b) Implementasi kode di sini
plt.figure(figsize=(10,7))
sns.kdeplot(totalVolume, shade=True)
plt.vlines(x=np.mean(totalVolume), ymin=0, ymax=6*1e-7, color='blue', linestyle='--')
plt.vlines(x=np.median(totalVolume), ymin=0, ymax=6*1e-7, color='black', linestyle='--')
plt.vlines(x=scp.mode(totalVolume)[0][0], ymin=0, ymax=6*1e-7, color='red', linestyle='--')
plt.legend(['Total Volume', 'Mean', 'Median', 'Mode'], fontsize=12)
plt.show()

# %% [markdown]
# **Hasil analisis nomor 1b**
#
# Berdasarkan hasil citra yang terlihat pada nomor 1b, dapat dilihat bahwa nilai median dan mode berada cukup dekat. Sehingga keduanya tampak overlap. Namun berbeda dengan mean yang berada cukup jauh ke kanan dari median dan mode.
#
# Selain itu dari hasil citra terlihat bahwa distribusi data terlihat cukup balance antara kanan dan kirinya. Maka dari itu, dalam kasus ini median merupakan indikator yang cukup tepat untuk mengukur central tendency pada data ini.

# %% [markdown]
# (c) Tampilan matriks korelasi menggunakan Pearson dinilai kurang menarik untuk dilihat. Tampilkan matriks korelasi menggunakan heatmap!

# %%
# 1(c) Implementasi kode di sini
plt.figure(figsize=(16, 6))
map = sns.heatmap(avocado_df.corr(), vmin = -1, vmax = 1, annot = True)
map.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# (d) Gunakan visualisasi Bubble Plot untuk menampilkan hubungan linear antara atribut `Total Volume` dengan `Total Bags`! Kelompokkan data berdasarkan atribut `type`! Berikan analisis atau temuan anda dari hasil visualisasi ini!

# %%
# 1(d) Implementasi kode di sini
plt.rcParams['figure.figsize'] = [15, 8]
sns.scatterplot(
    data = avocado_df,
    x = "Total Volume",
    y = "Total Bags",
    size = "type",
    hue = 'type',
    legend = True,
    alpha = .5,
    sizes = (50, 200)
)
plt.show()

# %% [markdown]
# **Hasil analisis problem 1d**
#
# Berdasarkan hasil yang tercitra pada gambar diatas terlihat bahwa baik type conventional maupun organic mencitrakan bahwa jumlah bags berbanding lurus dengan jumlah volume. Itu artinya, semakin tinggi volumenya maka jumlah bagsnya akan semakin banyak pula, vice versa.
#
# Selain itu dapat dilihat bahwa kaitan antara total volume dan total bags pada type organic lebih dense ketimbang pada type conventional. Pada awalnya type conventional terlihat as dense as type organic, namun seiring bertambangnya volume, korelasi terlihat semakin sparse.

# %% [markdown]
# ### **SOAL 2: Data Visualization**
#
# Untuk setiap sub-soal, pilih salah satu dari visualisasi berikut:
# * Pie chart
# * Bar chart
# * Scatter plot
# * Box plot
# * Histogram
# * Line graph
#
# Beberapa kasus terkadang memiliki lebih dari satu "jawaban yang tepat", karena ada banyak cara untuk visualisasi data. Pilihlah yang menurut Anda paling cocok berdasarkan kasus yang diberikan.
#
# **Secara eksplisit, tulis chart apa yang Anda pilih dan alasannya.**
#
# (a) Buatlah visualisasi untuk melihat rata-rata alpukat yang terjual di setiap region. Apakah California adalah region dengan rata-rata penjualan alpukat terbanyak? (Asumsi `TotalUS` bukanlah sebuah region)

# %%
# 2(a) Implementasi kode di sini

#Dropping Region TotalUS
totalUSIndex = avocado_df[avocado_df['region'] == 'TotalUS'].index
withoutTotalUS = avocado_df.drop(list(totalUSIndex), axis = 0)

region = pd.unique(withoutTotalUS['region'])
avgVolumeEachRegion = []
result = withoutTotalUS.groupby('region').mean()['Total Volume']

for i in result:
  avgVolumeEachRegion.append(i)

df = pd.DataFrame({
    'Region': region,
    'Avg Volume': avgVolumeEachRegion,
})
df.sort_values(by='Avg Volume', inplace=True)

plt.bar(df['Region'], df['Avg Volume'])
plt.ylabel('Average Volume Sold (Millions)')
plt.title('Average Avocado Sold each Region in US')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Hasil analisis nomor 2a**
#
# California bukanlah region dengan rata-rata penjualan alpukat tertinggi di US. Namun California berada di posisi 2 dengan rata-rata penjualan sekitar 3.04 x 10^6, dibawah West dengan rata-rata penjualan berkisar 3.21 x 10^6

# %% [markdown]
# (b) Buatlah visualisasi yang menunjukkan average price per tahun. Dari visualisasi, di antara 2 tahun apakah yang memiliki perbedaan average price yang tertinggi?

# %%
# 2(b) Implementasi kode di sini
avgPriceEachYear = []
year = pd.unique(avocado_df['year'])
result = avocado_df.groupby('year').mean()['AveragePrice']

for i in result:
  avgPriceEachYear.append(i)

plt.plot(
  year,
  result,
  marker='o',
)
plt.title('Average Avocado Price Selling per Year')
plt.xlabel('year')
plt.ylabel('average price selling ($)')
plt.show()

# %% [markdown]
# **Hasil analisis nomor 2b**
#
# Dari hasil citra diatas dapat terlihat bahwa perbedaan average price tertinggi terdapat pada tahun 2017 dengan tahun 2016. Pada tahun 2017 average price menyentuh angka USD 1.51 sedangkan pada tahun sebelumnya, yakni tahun 2016 average price berada di angka USD 1.33

# %% [markdown]
# (c) Buatlah visualisasi dari persentase total volume alpukat yang terjual dengan average price >= 1.4 dari masing-masing tipe. Berapakah persentase dari organic avocadoes yang terjual dengan average price >= 1.4?

# %%
# 2(c) Implementasi kode di sini
avocadoSpecAvg = avocado_df[avocado_df['AveragePrice'] >= 1.4]
avoType = pd.unique(avocado_df['type'])
avgPriceEachType = list(avocado_df.groupby('type').mean()['AveragePrice'])
totalVolumeEachType = list(avocadoSpecAvg.groupby('type').sum()['Total Volume'])

plt.pie(
    totalVolumeEachType,
    labels=avoType,
    autopct='%1.1f%%',
)
plt.show()

# %% [markdown]
# **Hasil analisis nomor 2c**
#
# Persentasi organic avocadoes yang terjual dengan average price >= 1.4 sebesar 19.1% dari total seluruh penjualan yang memiliki average price >= 1.4

# %% [markdown]
# (d) Buatlah visualisasi untuk melihat pola dari `AveragePrice` dan `Small Bags`. Berdasarkan apa yang Anda lihat, apakah ada outlier(s) untuk alpukat dengan average price sekitar 1.0?

# %%
# 2(d) Implementasi kode di sini
avePrice = list(avocado_df['AveragePrice'])
smallBags = list(avocado_df['Small Bags'])

plt.xlabel('average price')
plt.ylabel('number of small bags')
plt.scatter(avePrice, smallBags)
plt.show()

# %% [markdown]
# **Hasil analisis nomor 2d**
#
# Dari gambar yang tercitra diatas, dapat dilihat bahwa rata rata masyarakat cenderung untuk membeli avocado dengan harga yang lebih murah. Hal ini dapat ditandai dengan cukup dense pada rentang harga sekitar 0.6 hingga 1.6
#
# Dari citra yang ditampilkan diatas, terlihat terdapat 2 outliers (arguably 3 outliers). Hal ini dapat ditandai entah saat itu sedang terdapat diskon besar-besaran sehingga masyarakat cenderung berbondong-bondong belanja atau ada trigger lainnya.

# %% [markdown]
# (e) Buatlah visualisasi untuk melihat apakah ada outliers di atribut `Total Bags` untuk setiap region. Berikan satu contoh region yang terlihat tidak memiliki outlier.

# %%
# 2(e) Implementasi kode di sini

#Dropping Region TotalUS
totalUSIndex = avocado_df[avocado_df['region'] == 'TotalUS'].index
withoutTotalUS = avocado_df.drop(list(totalUSIndex), axis = 0)

fig = px.box(withoutTotalUS, x='region', y='Total Bags')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2af54db4-15cb-4f66-8e0d-68a61f8d234b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2af54db4-15cb-4f66-8e0d-68a61f8d234b")) {                    Plotly.newPlot(                        "2af54db4-15cb-4f66-8e0d-68a61f8d234b",                        [{"alignmentgroup":"True","hovertemplate":"region=%{x}<br>Total Bags=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Albany","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","Atlanta","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","BaltimoreWashington","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boise","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","Boston","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","BuffaloRochester","Buffalo ...

# %% [markdown]
# **Hasil analisis nomor 2e**
#
# Pada proses analisis nomor 2e, saya memutuskan untuk menghilangkan TotalUS dari data karena menurut saya TotalUS dapat mengacaukan seluruh citra data yang ada.
#
# Dari hasil citra yang terdapat pada gambar diatas, secara sekilas terlihat bahwa region Northeast dan Plains tidak memiliki outlier seperti pada Southeast.

# %% [markdown]
# (f) Buatlah perbandingan distribusi data dari jumlah alpukat yang dijual di California dengan GreatLakes. Berikan analisis Anda.

# %%
# 2(f) Implementasi kode di sini
CA = list(avocado_df[avocado_df['region'] == 'California'].index)
GL = list(avocado_df[avocado_df['region'] == 'GreatLakes'].index)
CAGL = CA + GL

sns.boxplot(x='region', y="Total Volume", data=avocado_df.loc[CAGL])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Hasil analisis nomor 2f**
#
# Pada gambar diatas dapat terlihat bahwa Q3 pada region California lebih tinggi ketimbang Q3 pada GreatLakes sedangkan Q1 pada kedua region tampak sama. Selain itu IQR pada region California terlihat lebih tinggi ketimbang pada region GreatLakes. Menurut hipotesis saya, hal ini dapat terjadi karena kemungkinan besar persebaran data pada region California lebih sparse ketimbang pada region GreatLakes yang cenderung lebih dense.
#
# Selain itu, IQR pada kedua region tampak hampir mepet dengan batas minimum dari masing-masing boxplot. Formula dari batas minimum boxplot adalah (Q1 - 1.5 * IQR). Apabila diasumsikan Q1 pada kedua region hampir sama, itu artinya satu-satunya faktor yang mempengaruhi kalkulasi (Q1 - 1.5 x IQR) adalah IQR itu sendiri.
#
# Formula dari IQR adalah jarak antara 75th percentile dengan 25th percentile. Maka dari itu, terbukti bahwa persebaran data pada region California lebih sparse ketimbang pada region GreatLakes.
